# %%
import json
import xmltodict
import os
import sys
from xml.etree import ElementTree as ET


def DFS(node):
    if node.tag=="p" :
        print("{\"question\": \"",end="")
        #print(node.attrib)
        for child in node: 
            str=child.text
            strc=""
            for i in str:
                if (i=='"'):
                    strc+='\\'
                    strc+=i
                else: 
                    strc+=i
            print(strc,end="")
        print("\","+"\"answer\":[\"\"] }")
        return 0
    for child in node:
        DFS(child)

#def DFS(node):
tree=ET.parse('wmttest2022.src.en-zh.xml')
root=tree.getroot()
print(root.tag)
print(root.attrib)
for child in root:
    print(child.tag,child.attrib)
f = open('convert-en-zh.jsonl', 'w', encoding="utf-8")
sys.stdout = f
DFS(root)
#DFS(root)
#获取xml文件
#读取xml文件内容
    
#将读取的xml内容转为json

# %%
import json
import xmltodict
import os
import sys
from xml.etree import ElementTree as ET


def DFS(node):
    if node.tag=="p" :
        print("{\"question\": \"",end="")
        #print(node.attrib)
        for child in node: 
            str=child.text
            strc=""
            for i in str:
                if (i=='"'):
                    strc+='\\'
                    strc+=i
                else: 
                    strc+=i
            print(strc,end="")
        print("\","+"\"answer\":[\"\"] }")
        return 0
    for child in node:
        DFS(child)

#def DFS(node):
tree=ET.parse('wmttest2022.src.zh-en.xml')
root=tree.getroot()
print(root.tag)
print(root.attrib)
for child in root:
    print(child.tag,child.attrib)
f = open('convert-zh-en.jsonl', 'w', encoding="utf-8")
sys.stdout = f
DFS(root)
